# %% [markdown]
# <a href="https://colab.research.google.com/github/godines51/AWS/blob/main/Atividade_cuda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt search cuda
# Out:
# Sorting... Done
# Full Text Search... Done
# bart-cuda/jammy 0.7.00-5 amd64
#   tools for computational magnetic resonance imaging
#
# boinc-client-nvidia-cuda/jammy 7.18.1+dfsg-4 amd64
#   metapackage for CUDA-savvy BOINC client and manager
#
# cublasmp-cuda-11/unknown 0.2.0.385-1 amd64
#   NVIDIA cuBLASMp for CUDA 11
#
# cublasmp-cuda-12/unknown 0.2.0.385-1 amd64
#   NVIDIA cuBLASMp for CUDA 12
#
# cuda/unknown 12.4.1-1 amd64
#   CUDA meta-package
#
# cuda-11-7/unknown 11.7.1-1 amd64
#   CUDA 11.7 meta-package
#
# cuda-11-8/unknown 11.8.0-1 amd64
#   CUDA 11.8 meta-package
#
# cuda-12-0/unknown 12.0.1-1 amd64
#   CUDA 12.0 meta-package
#
# cuda-12-1/unknown 12.1.1-1 amd64
#   CUDA 12.1 meta-package
#
# cuda-12-2/unknown 12.2.2-1 amd64
#   CUDA 12.2 meta-package
#
# cuda-12-3/unknown 12.3.2-1 amd64
#   CUDA 12.3 meta-package
#
# cuda-12-4/unknown 12.4.1-1 amd64
#   CUDA 12.4 meta-package
#
# cuda-cccl-11-7/unknown 11.7.91-1 amd64
#   CUDA CCCL
#
# cuda-cccl-11-8/unknown 11.8.89-1 amd64
#   CUDA CCCL
#
# cuda-cccl-12-0/unknown 12.0.140-1 amd64
#   CUDA CCCL
#
# cuda-cccl-12-1/unknown 12.1.109-1 amd64
#   CUDA CCCL
#
# cuda-cccl-12-2/unknown,now 12.2.140-1 amd64 [installed,automatic]
#   CUDA CCCL
#
# cuda-cccl-12-3/unknown 12.3.101-1 amd64
#   CUDA CCCL
#
# cuda-cccl-12-4/unknown 12.4.127-1 amd64
#   CUDA CCCL
#
# cuda-command-line-tools-11-7/unknown 11.7.1-1 amd64
#   CUDA command-line tools
#
# cuda-command-line-tools-11-8/unknown 11.8.0-1 amd64
#   CUDA command-line tools
#
# cuda-command-line-tools-12-0/unknown 12.0.1-1 amd64
#   CUDA command-line tools
#
# cuda-command-line-tools-12-1/unknown 12.1.1-1 amd64
#   CUDA command-line tools
#
# cuda-command-line-tools-12-2/unknown,now 12.2.2-1 amd64 [installed]
#   CUDA command-line tools
#
# cuda-command-line-tools-12-3/unknown 12.3.2-1 amd64
#   CUDA command-line tools
#
# cuda-command-line-tools-12-4/unknown 12.4.1-1 amd64
#   CUDA command-line tools
#
# cuda-compat-11-7/unknown 515.105.01-1 amd64
#   CUDA Compatibility Platform
#
# cuda-compat-11-8/unknown 520.61.05-1 amd64
#   CUDA Compatibility Platform
#
# cuda-compat-12-0/unknown 525.147.05-1 amd64
#   CUDA Compatibility Platform
#
# cuda-compat-12-1/unknown 530.30.02-1 amd64
#   CUDA Compatibility Platform
#
# cuda-compat-12-2/unknown 535.161.08-1 amd64 [upgradable from: 535.129.03-1]
#   CUDA Compatibility Platform
#
# cuda-compat-12-3/unknown 545.23.08-1 amd64
#   CUDA Compatibility Platform
#
# cuda-compat-12-4/unknown 550.54.15-1 amd64
#   CUDA Compatibility Platform
#
# cuda-compiler-11-7/unknown 11.7.1-1 amd64
#   CUDA compiler
#
# cuda-compiler-11-8/unknown 11.8.0-1 amd64
#   CUDA compiler
#
# cuda-compiler-12-0/unknown 12.0.1-1 amd64
#   CUDA compiler
#
# cuda-compiler-12-1/unknown 12.1.1-1 amd64
#   CUDA compiler
#
# cuda-compiler-12-2/unknown,now 12.2.2-1 amd64 [installed,automatic]
#   CUDA compiler
#
# cuda-compiler-12-3/unknown 12.3.2-1 amd64
#   CUDA compiler
#
# cuda-compiler-12-4/unknown 12.4.1-1 amd64
#   CUDA compiler
#
# cuda-crt-12-2/unknown,now 12.2.140-1 amd64 [installed,automatic]
#   CUDA crt
#
# cuda-crt-12-3/unknown 12.3.107-1 amd64
#   CUDA crt
#
# cuda-crt-12-4/unknown 12.4.131-1 amd64
#   CUDA crt
#
# cuda-cudart-11-7/unknown 11.7.99-1 amd64
#   CUDA Runtime native Libraries
#
# cuda-cudart-11-8/unknown 11.8.89-1 amd64
#   CUDA Runtime native Libraries
#
# cuda-cudart-12-0/unknown 12.0.146-1 amd64
#   CUDA Runtime native Libraries
#
# cuda-cudart-12-1/unknown 12.1.105-1 amd64
#   CUDA Runtime native Libraries
#
# cuda-cudart-12-2/unknown,now 12.2.140-1 amd64 [installed]
#   CUDA Runtime native Libraries
#
# cuda-cudart-12-3/unknown 12.3.101-1 amd64
#   CUDA Runtime native Libraries
#
# cuda-cudart-12-4/unknown 12.4.127-1 amd64
#   CUDA Runtime native Libraries
#
# cuda-cudart-dev-11-7/unknown 11.7.99-1 amd64
#   CUDA Runtime native dev links, headers
#
# cuda-cudart-dev-11-8/unknown 11.8.89-1 amd64
#   CUDA Runtime native dev links, headers
#
# cuda-cudart-dev-12-0/unknown 12.0.146-1 amd64
#   CUDA Runtime native dev links, headers
#
# cuda-cudart-dev-12-1/unknown 12.1.105-1 amd64
#   CUDA Runtime native dev links, headers
#
# cuda-cudart-dev-12-2/unknown,now 12.2.140-1 amd64 [installed]
#   CUDA Runtime native dev links, headers
#
# cuda-cudart-dev-12-3/unknown 12.3.101-1 amd64
#   CUDA Runtime native dev links, headers
#
# cuda-cudart-dev-12-4/unknown 12.4.127-1 amd64
#   CUDA Runtime native dev links, headers
#
# cuda-cuobjdump-11-7/unknown 11.7.91-1 amd64
#   CUDA cuobjdump
#
# cuda-cuobjdump-11-8/unknown 11.8.86-1 amd64
#   CUDA cuobjdump
#
# cuda-cuobjdump-12-0/unknown 12.0.140-1 amd64
#   CUDA cuobjdump
#
# cuda-cuobjdump-12-1/unknown 12.1.111-1 amd64
#   CUDA cuobjdump
#
# cuda-cuobjdump-12-2/unknown,now 12.2.140-1 amd64 [installed,automatic]
#   CUDA cuobjdump
#
# cuda-cuobjdump-12-3/unknown 12.3.101-1 amd64
#   CUDA cuobjdump
#
# cuda-cuobjdump-12-4/unknown 12.4.127-1 amd64
#   CUDA cuobjdump
#
# cuda-cupti-11-7/unknown 11.7.101-1 amd64
#   CUDA profiling tools runtime libs.
#
# cuda-cupti-11-8/unknown 11.8.87-1 amd64
#   CUDA profiling tools runtime libs.
#
# cuda-cupti-12-0/unknown 12.0.146-1 amd64
#   CUDA profiling tools runtime libs.
#
# cuda-cupti-12-1/unknown 12.1.105-1 amd64
#   CUDA profiling tools runtime libs.
#
# cuda-cupti-12-2/unknown,now 12.2.142-1 amd64 [installed,automatic]
#   CUDA profiling tools runtime libs.
#
# cuda-cupti-12-3/unknown 12.3.101-1 amd64
#   CUDA profiling tools runtime libs.
#
# cuda-cupti-12-4/unknown 12.4.127-1 amd64
#   CUDA profiling tools runtime libs.
#
# cuda-cupti-dev-11-7/unknown 11.7.101-1 amd64
#   CUDA profiling tools interface.
#
# cuda-cupti-dev-11-8/unknown 11.8.87-1 amd64
#   CUDA profiling tools interface.
#
# cuda-cupti-dev-12-0/unknown 12.0.146-1 amd64
#   CUDA profiling tools interface.
#
# cuda-cupti-dev-12-1/unknown 12.1.105-1 amd64
#   CUDA profiling tools interface.
#
# cuda-cupti-dev-12-2/unknown,now 12.2.142-1 amd64 [installed,automatic]
#   CUDA profiling tools interface.
#
# cuda-cupti-dev-12-3/unknown 12.3.101-1 amd64
#   CUDA profiling tools interface.
#
# cuda-cupti-dev-12-4/unknown 12.4.127-1 amd64
#   CUDA profiling tools interface.
#
# cuda-cuxxfilt-11-7/unknown 11.7.91-1 amd64
#   CUDA cuxxfilt
#
# cuda-cuxxfilt-11-8/unknown 11.8.86-1 amd64
#   CUDA cuxxfilt
#
# cuda-cuxxfilt-12-0/unknown 12.0.140-1 amd64
#   CUDA cuxxfilt
#
# cuda-cuxxfilt-12-1/unknown 12.1.105-1 amd64
#   CUDA cuxxfilt
#
# cuda-cuxxfilt-12-2/unknown,now 12.2.140-1 amd64 [installed,automatic]
#   CUDA cuxxfilt
#
# cuda-cuxxfilt-12-3/unknown 12.3.101-1 amd64
#   CUDA cuxxfilt
#
# cuda-cuxxfilt-12-4/unknown 12.4.127-1 amd64
#   CUDA cuxxfilt
#
# cuda-demo-suite-11-7/unknown 11.7.91-1 amd64
#   Demo suite for CUDA
#
# cuda-demo-suite-11-8/unknown 11.8.86-1 amd64
#   Demo suite for CUDA
#
# cuda-demo-suite-12-0/unknown 12.0.140-1 amd64
#   Demo suite for CUDA
#
# cuda-demo-suite-12-1/unknown 12.1.105-1 amd64
#   Demo suite for CUDA
#
# cuda-demo-suite-12-2/unknown 12.2.140-1 amd64
#   Demo suite for CUDA
#
# cuda-demo-suite-12-3/unknown 12.3.101-1 amd64
#   Demo suite for CUDA
#
# cuda-demo-suite-12-4/unknown 12.4.127-1 amd64
#   Demo suite for CUDA
#
# cuda-documentation-11-7/unknown 11.7.91-1 amd64
#   CUDA documentation
#
# cuda-documentation-11-8/unknown 11.8.86-1 amd64
#   CUDA documentation
#
# cuda-documentation-12-0/unknown 12.0.140-1 amd64
#   CUDA documentation
#
# cuda-documentation-12-1/unknown 12.1.105-1 amd64
#   CUDA documentation
#
# cuda-documentation-12-2/unknown 12.2.140-1 amd64
#   CUDA documentation
#
# cuda-documentation-12-3/unknown 12.3.101-1 amd64
#   CUDA documentation
#
# cuda-documentation-12-4/unknown 12.4.127-1 amd64
#   CUDA documentation
#
# cuda-driver-dev-11-7/unknown 11.7.99-1 amd64
#   CUDA Driver native dev stub library
#
# cuda-driver-dev-11-8/unknown 11.8.89-1 amd64
#   CUDA Driver native dev stub library
#
# cuda-driver-dev-12-0/unknown 12.0.146-1 amd64
#   CUDA Driver native dev stub library
#
# cuda-driver-dev-12-1/unknown 12.1.105-1 amd64
#   CUDA Driver native dev stub library
#
# cuda-driver-dev-12-2/unknown,now 12.2.140-1 amd64 [installed,automatic]
#   CUDA Driver native dev stub library
#
# cuda-driver-dev-12-3/unknown 12.3.101-1 amd64
#   CUDA Driver native dev stub library
#
# cuda-driver-dev-12-4/unknown 12.4.127-1 amd64
#   CUDA Driver native dev stub library
#
# cuda-drivers/unknown 550.54.15-1 amd64
#   CUDA Driver meta-package, branch-agnostic
#
# cuda-drivers-515/unknown 515.105.01-1 amd64
#   CUDA Driver meta-package, branch-specific
#
# cuda-drivers-520/unknown 520.61.05-1 amd64
#   CUDA Driver meta-package, branch-specific
#
# cuda-drivers-525/unknown 525.147.05-1 amd64
#   CUDA Driver meta-package, branch-specific
#
# cuda-drivers-530/unknown 530.30.02-1 amd64
#   CUDA Driver meta-package, branch-specific
#
# cuda-drivers-535/unknown 535.161.08-1 amd64
#   CUDA Driver meta-package, branch-specific
#
# cuda-drivers-545/unknown 545.23.08-1 amd64
#   CUDA Driver meta-package, branch-specific
#
# cuda-drivers-550/unknown 550.54.15-1 amd64
#   CUDA Driver meta-package, branch-specific
#
# cuda-drivers-fabricmanager/unknown 550.54.15-1 amd64
#   Meta-package for FM and Driver
#
# cuda-drivers-fabricmanager-450/jammy-updates,jammy-security 450.248.02-0ubuntu0.22.04.1 amd64
#   Meta-package for FM and Driver
#
# cuda-drivers-fabricmanager-460/jammy-updates,jammy-security 510.85.02-0ubuntu0.22.04.1 amd64
#   Transitional package for cuda-drivers-fabricmanager-510
#
# cuda-drivers-fabricmanager-470/jammy-updates,jammy-security 470.239.06-0ubuntu0.22.04.1 amd64
#   Meta-package for FM and Driver
#
# cuda-drivers-fabricmanager-510/jammy-updates,jammy-security 515.105.01-0ubuntu0.22.04.1 amd64
#   Transitional package for cuda-drivers-fabricmanager-515
#
# cuda-drivers-fabricmanager-515/unknown 515.105.01-1 amd64
#   Meta-package for FM and Driver
#
# cuda-drivers-fabricmanager-520/unknown 520.61.05-1 amd64
#   Meta-package for FM and Driver
#
# cuda-drivers-fabricmanager-525/unknown 525.147.05-1 amd64
#   Meta-package for FM and Driver
#
# cuda-drivers-fabricmanager-530/unknown 530.30.02-1 amd64
#   Meta-package for FM and Driver
#
# cuda-drivers-fabricmanager-535/unknown 535.161.08-1 amd64
#   Meta-package for FM and Driver
#
# cuda-drivers-fabricmanager-545/unknown 545.23.08-1 amd64
#   Meta-package for FM and Driver
#
# cuda-drivers-fabricmanager-550/unknown 550.54.15-1 amd64
#   Meta-package for FM and Driver
#
# cuda-gdb-11-7/unknown 11.7.91-1 amd64
#   CUDA-GDB
#
# cuda-gdb-11-8/unknown 11.8.86-1 amd64
#   CUDA-GDB
#
# cuda-gdb-12-0/unknown 12.0.140-1 amd64
#   CUDA-GDB
#
# cuda-gdb-12-1/unknown 12.1.105-1 amd64
#   CUDA-GDB
#
# cuda-gdb-12-2/unknown,now 12.2.140-1 amd64 [installed,automatic]
#   CUDA-GDB
#
# cuda-gdb-12-3/unknown 12.3.101-1 amd64
#   CUDA-GDB
#
# cuda-gdb-12-4/unknown 12.4.127-1 amd64
#   CUDA-GDB
#
# cuda-gdb-src-11-7/unknown 11.7.91-1 amd64
#   Contains the source code for cuda-gdb
#
# cuda-gdb-src-11-8/unknown 11.8.86-1 amd64
#   Contains the source code for cuda-gdb
#
# cuda-gdb-src-12-0/unknown 12.0.140-1 amd64
#   Contains the source code for cuda-gdb
#
# cuda-gdb-src-12-1/unknown 12.1.105-1 amd64
#   Contains the source code for cuda-gdb
#
# cuda-gdb-src-12-2/unknown 12.2.140-1 amd64
#   Contains the source code for cuda-gdb
#
# cuda-gdb-src-12-3/unknown 12.3.101-1 amd64
#   Contains the source code for cuda-gdb
#
# cuda-gdb-src-12-4/unknown 12.4.127-1 amd64
#   Contains the source code for cuda-gdb
#
# cuda-keyring/unknown 1.1-1 all [upgradable from: 1.0-1]
#   GPG keyring for the CUDA repository
#
# cuda-libraries-11-7/unknown 11.7.1-1 amd64
#   CUDA Libraries 11.7 meta-package
#
# cuda-libraries-11-8/unknown 11.8.0-1 amd64
#   CUDA Libraries 11.8 meta-package
#
# cuda-libraries-12-0/unknown 12.0.1-1 amd64
#   CUDA Libraries 12.0 meta-package
#
# cuda-libraries-12-1/unknown 12.1.1-1 amd64
#   CUDA Libraries 12.1 meta-package
#
# cuda-libraries-12-2/unknown,now 12.2.2-1 amd64 [installed]
#   CUDA Libraries 12.2 meta-package
#
# cuda-libraries-12-3/unknown 12.3.2-1 amd64
#   CUDA Libraries 12.3 meta-package
#
# cuda-libraries-12-4/unknown 12.4.1-1 amd64
#   CUDA Libraries 12.4 meta-package
#
# cuda-libraries-dev-11-7/unknown 11.7.1-1 amd64
#   CUDA Libraries 11.7 development meta-package
#
# cuda-libraries-dev-11-8/unknown 11.8.0-1 amd64
#   CUDA Libraries 11.8 development meta-package
#
# cuda-libraries-dev-12-0/unknown 12.0.1-1 amd64
#   CUDA Libraries 12.0 development meta-package
#
# cuda-libraries-dev-12-1/unknown 12.1.1-1 amd64
#   CUDA Libraries 12.1 development meta-package
#
# cuda-libraries-dev-12-2/unknown,now 12.2.2-1 amd64 [installed]
#   CUDA Libraries 12.2 development meta-package
#
# cuda-libraries-dev-12-3/unknown 12.3.2-1 amd64
#   CUDA Libraries 12.3 development meta-package
#
# cuda-libraries-dev-12-4/unknown 12.4.1-1 amd64
#   CUDA Libraries 12.4 development meta-package
#
# cuda-memcheck-11-7/unknown 11.7.91-1 amd64
#   CUDA-MEMCHECK
#
# cuda-memcheck-11-8/unknown 11.8.86-1 amd64
#   CUDA-MEMCHECK
#
# cuda-minimal-build-11-7/unknown 11.7.1-1 amd64
#   Minimal CUDA 11.7 toolkit build packages.
#
# cuda-minimal-build-11-8/unknown 11.8.0-1 amd64
#   Minimal CUDA 11.8 toolkit build packages.
#
# cuda-minimal-build-12-0/unknown 12.0.1-1 amd64
#   Minimal CUDA 12.0 toolkit build packages.
#
# cuda-minimal-build-12-1/unknown 12.1.1-1 amd64
#   Minimal CUDA 12.1 toolkit build packages.
#
# cuda-minimal-build-12-2/unknown,now 12.2.2-1 amd64 [installed]
#   Minimal CUDA 12.2 toolkit build packages.
#
# cuda-minimal-build-12-3/unknown 12.3.2-1 amd64
#   Minimal CUDA 12.3 toolkit build packages.
#
# cuda-minimal-build-12-4/unknown 12.4.1-1 amd64
#   Minimal CUDA 12.4 toolkit build packages.
#
# cuda-nsight-11-7/unknown 11.7.91-1 amd64
#   CUDA nsight
#
# cuda-nsight-11-8/unknown 11.8.86-1 amd64
#   CUDA nsight
#
# cuda-nsight-12-0/unknown 12.0.140-1 amd64
#   CUDA nsight
#
# cuda-nsight-12-1/unknown 12.1.105-1 amd64
#   CUDA nsight
#
# cuda-nsight-12-2/unknown 12.2.144-1 amd64
#   CUDA nsight
#
# cuda-nsight-12-3/unknown 12.3.101-1 amd64
#   CUDA nsight
#
# cuda-nsight-12-4/unknown 12.4.127-1 amd64
#   CUDA nsight
#
# cuda-nsight-compute-11-7/unknown 11.7.1-1 amd64
#   NVIDIA Nsight Compute
#
# cuda-nsight-compute-11-8/unknown 11.8.0-1 amd64
#   NVIDIA Nsight Compute
#
# cuda-nsight-compute-12-0/unknown 12.0.1-1 amd64
#   NVIDIA Nsight Compute
#
# cuda-nsight-compute-12-1/unknown 12.1.1-1 amd64
#   NVIDIA Nsight Compute
#
# cuda-nsight-compute-12-2/unknown,now 12.2.2-1 amd64 [installed]
#   NVIDIA Nsight Compute
#
# cuda-nsight-compute-12-3/unknown 12.3.2-1 amd64
#   NVIDIA Nsight Compute
#
# cuda-nsight-compute-12-4/unknown 12.4.1-1 amd64
#   NVIDIA Nsight Compute
#
# cuda-nsight-systems-11-7/unknown 11.7.1-1 amd64
#   NVIDIA Nsight Systems
#
# cuda-nsight-systems-11-8/unknown 11.8.0-1 amd64
#   NVIDIA Nsight Systems
#
# cuda-nsight-systems-12-0/unknown 12.0.1-1 amd64
#   NVIDIA Nsight Systems
#
# cuda-nsight-systems-12-1/unknown 12.1.1-1 amd64
#   NVIDIA Nsight Systems
#
# cuda-nsight-systems-12-2/unknown 12.2.2-1 amd64
#   NVIDIA Nsight Systems
#
# cuda-nsight-systems-12-3/unknown 12.3.2-1 amd64
#   NVIDIA Nsight Systems
#
# cuda-nsight-systems-12-4/unknown 12.4.1-1 amd64
#   NVIDIA Nsight Systems
#
# cuda-nvcc-11-7/unknown 11.7.99-1 amd64
#   CUDA nvcc
#
# cuda-nvcc-11-8/unknown 11.8.89-1 amd64
#   CUDA nvcc
#
# cuda-nvcc-12-0/unknown 12.0.140-1 amd64
#   CUDA nvcc
#
# cuda-nvcc-12-1/unknown 12.1.105-1 amd64
#   CUDA nvcc
#
# cuda-nvcc-12-2/unknown,now 12.2.140-1 amd64 [installed,automatic]
#   CUDA nvcc
#
# cuda-nvcc-12-3/unknown 12.3.107-1 amd64
#   CUDA nvcc
#
# cuda-nvcc-12-4/unknown 12.4.131-1 amd64
#   CUDA nvcc
#
# cuda-nvdisasm-11-7/unknown 11.7.91-1 amd64
#   CUDA disassembler
#
# cuda-nvdisasm-11-8/unknown 11.8.86-1 amd64
#   CUDA disassembler
#
# cuda-nvdisasm-12-0/unknown 12.0.140-1 amd64
#   CUDA disassembler
#
# cuda-nvdisasm-12-1/unknown 12.1.105-1 amd64
#   CUDA disassembler
#
# cuda-nvdisasm-12-2/unknown,now 12.2.140-1 amd64 [installed,automatic]
#   CUDA disassembler
#
# cuda-nvdisasm-12-3/unknown 12.3.101-1 amd64
#   CUDA disassembler
#
# cuda-nvdisasm-12-4/unknown 12.4.127-1 amd64
#   CUDA disassembler
#
# cuda-nvml-dev-11-7/unknown 11.7.91-1 amd64
#   NVML native dev links, headers
#
# cuda-nvml-dev-11-8/unknown 11.8.86-1 amd64
#   NVML native dev links, headers
#
# cuda-nvml-dev-12-0/unknown 12.0.140-1 amd64
#   NVML native dev links, headers
#
# cuda-nvml-dev-12-1/unknown 12.1.105-1 amd64
#   NVML native dev links, headers
#
# cuda-nvml-dev-12-2/unknown,now 12.2.140-1 amd64 [installed]
#   NVML native dev links, headers
#
# cuda-nvml-dev-12-3/unknown 12.3.101-1 amd64
#   NVML native dev links, headers
#
# cuda-nvml-dev-12-4/unknown 12.4.127-1 amd64
#   NVML native dev links, headers
#
# cuda-nvprof-11-7/unknown 11.7.101-1 amd64
#   CUDA Profiler tools
#
# cuda-nvprof-11-8/unknown 11.8.87-1 amd64
#   CUDA Profiler tools
#
# cuda-nvprof-12-0/unknown 12.0.146-1 amd64
#   CUDA Profiler tools
#
# cuda-nvprof-12-1/unknown 12.1.105-1 amd64
#   CUDA Profiler tools
#
# cuda-nvprof-12-2/unknown,now 12.2.142-1 amd64 [installed]
#   CUDA Profiler tools
#
# cuda-nvprof-12-3/unknown 12.3.101-1 amd64
#   CUDA Profiler tools
#
# cuda-nvprof-12-4/unknown 12.4.127-1 amd64
#   CUDA Profiler tools
#
# cuda-nvprune-11-7/unknown 11.7.91-1 amd64
#   CUDA nvprune
#
# cuda-nvprune-11-8/unknown 11.8.86-1 amd64
#   CUDA nvprune
#
# cuda-nvprune-12-0/unknown 12.0.140-1 amd64
#   CUDA nvprune
#
# cuda-nvprune-12-1/unknown 12.1.105-1 amd64
#   CUDA nvprune
#
# cuda-nvprune-12-2/unknown,now 12.2.140-1 amd64 [installed,automatic]
#   CUDA nvprune
#
# cuda-nvprune-12-3/unknown 12.3.101-1 amd64
#   CUDA nvprune
#
# cuda-nvprune-12-4/unknown 12.4.127-1 amd64
#   CUDA nvprune
#
# cuda-nvrtc-11-7/unknown 11.7.99-1 amd64
#   NVRTC native runtime libraries
#
# cuda-nvrtc-11-8/unknown 11.8.89-1 amd64
#   NVRTC native runtime libraries
#
# cuda-nvrtc-12-0/unknown 12.0.140-1 amd64
#   NVRTC native runtime libraries
#
# cuda-nvrtc-12-1/unknown 12.1.105-1 amd64
#   NVRTC native runtime libraries
#
# cuda-nvrtc-12-2/unknown,now 12.2.140-1 amd64 [installed,automatic]
#   NVRTC native runtime libraries
#
# cuda-nvrtc-12-3/unknown 12.3.107-1 amd64
#   NVRTC native runtime libraries
#
# cuda-nvrtc-12-4/unknown 12.4.127-1 amd64
#   NVRTC native runtime libraries
#
# cuda-nvrtc-dev-11-7/unknown 11.7.99-1 amd64
#   NVRTC native dev links, headers
#
# cuda-nvrtc-dev-11-8/unknown 11.8.89-1 amd64
#   NVRTC native dev links, headers
#
# cuda-nvrtc-dev-12-0/unknown 12.0.140-1 amd64
#   NVRTC native dev links, headers
#
# cuda-nvrtc-dev-12-1/unknown 12.1.105-1 amd64
#   NVRTC native dev links, headers
#
# cuda-nvrtc-dev-12-2/unknown,now 12.2.140-1 amd64 [installed,automatic]
#   NVRTC native dev links, headers
#
# cuda-nvrtc-dev-12-3/unknown 12.3.107-1 amd64
#   NVRTC native dev links, headers
#
# cuda-nvrtc-dev-12-4/unknown 12.4.127-1 amd64
#   NVRTC native dev links, headers
#
# cuda-nvtx-11-7/unknown 11.7.91-1 amd64
#   NVIDIA Tools Extension
#
# cuda-nvtx-11-8/unknown 11.8.86-1 amd64
#   NVIDIA Tools Extension
#
# cuda-nvtx-12-0/unknown 12.0.140-1 amd64
#   NVIDIA Tools Extension
#
# cuda-nvtx-12-1/unknown 12.1.105-1 amd64
#   NVIDIA Tools Extension
#
# cuda-nvtx-12-2/unknown,now 12.2.140-1 amd64 [installed]
#   NVIDIA Tools Extension
#
# cuda-nvtx-12-3/unknown 12.3.101-1 amd64
#   NVIDIA Tools Extension
#
# cuda-nvtx-12-4/unknown 12.4.127-1 amd64
#   NVIDIA Tools Extension
#
# cuda-nvvm-12-2/unknown,now 12.2.140-1 amd64 [installed,automatic]
#   CUDA nvvm
#
# cuda-nvvm-12-3/unknown 12.3.107-1 amd64
#   CUDA nvvm
#
# cuda-nvvm-12-4/unknown 12.4.131-1 amd64
#   CUDA nvvm
#
# cuda-nvvp-11-7/unknown 11.7.101-1 amd64
#   CUDA Profiler tools
#
# cuda-nvvp-11-8/unknown 11.8.87-1 amd64
#   CUDA Profiler tools
#
# cuda-nvvp-12-0/unknown 12.0.146-1 amd64
#   CUDA Profiler tools
#
# cuda-nvvp-12-1/unknown 12.1.105-1 amd64
#   CUDA Profiler tools
#
# cuda-nvvp-12-2/unknown 12.2.142-1 amd64
#   CUDA Profiler tools
#
# cuda-nvvp-12-3/unknown 12.3.101-1 amd64
#   CUDA Profiler tools
#
# cuda-nvvp-12-4/unknown 12.4.127-1 amd64
#   CUDA Profiler tools
#
# cuda-opencl-12-0/unknown 12.0.140-1 amd64
#   CUDA OpenCL native Libraries
#
# cuda-opencl-12-1/unknown 12.1.105-1 amd64
#   CUDA OpenCL native Libraries
#
# cuda-opencl-12-2/unknown,now 12.2.140-1 amd64 [installed,automatic]
#   CUDA OpenCL native Libraries
#
# cuda-opencl-12-3/unknown 12.3.101-1 amd64
#   CUDA OpenCL native Libraries
#
# cuda-opencl-12-4/unknown 12.4.127-1 amd64
#   CUDA OpenCL native Libraries
#
# cuda-opencl-dev-12-0/unknown 12.0.140-1 amd64
#   CUDA OpenCL native dev links, headers
#
# cuda-opencl-dev-12-1/unknown 12.1.105-1 amd64
#   CUDA OpenCL native dev links, headers
#
# cuda-opencl-dev-12-2/unknown,now 12.2.140-1 amd64 [installed,automatic]
#   CUDA OpenCL native dev links, headers
#
# cuda-opencl-dev-12-3/unknown 12.3.101-1 amd64
#   CUDA OpenCL native dev links, headers
#
# cuda-opencl-dev-12-4/unknown 12.4.127-1 amd64
#   CUDA OpenCL native dev links, headers
#
# cuda-profiler-api-11-8/unknown 11.8.86-1 amd64
#   CUDA Profiler API
#
# cuda-profiler-api-12-0/unknown 12.0.140-1 amd64
#   CUDA Profiler API
#
# cuda-profiler-api-12-1/unknown 12.1.105-1 amd64
#   CUDA Profiler API
#
# cuda-profiler-api-12-2/unknown,now 12.2.140-1 amd64 [installed,automatic]
#   CUDA Profiler API
#
# cuda-profiler-api-12-3/unknown 12.3.101-1 amd64
#   CUDA Profiler API
#
# cuda-profiler-api-12-4/unknown 12.4.127-1 amd64
#   CUDA Profiler API
#
# cuda-runtime-11-7/unknown 11.7.1-1 amd64
#   CUDA Runtime 11.7 meta-package
#
# cuda-runtime-11-8/unknown 11.8.0-1 amd64
#   CUDA Runtime 11.8 meta-package
#
# cuda-runtime-12-0/unknown 12.0.1-1 amd64
#   CUDA Runtime 12.0 meta-package
#
# cuda-runtime-12-1/unknown 12.1.1-1 amd64
#   CUDA Runtime 12.1 meta-package
#
# cuda-runtime-12-2/unknown 12.2.2-1 amd64
#   CUDA Runtime 12.2 meta-package
#
# cuda-runtime-12-3/unknown 12.3.2-1 amd64
#   CUDA Runtime 12.3 meta-package
#
# cuda-runtime-12-4/unknown 12.4.1-1 amd64
#   CUDA Runtime 12.4 meta-package
#
# cuda-sanitizer-11-7/unknown 11.7.91-1 amd64
#   CUDA Sanitizer
#
# cuda-sanitizer-11-8/unknown 11.8.86-1 amd64
#   CUDA Sanitizer
#
# cuda-sanitizer-12-0/unknown 12.0.140-1 amd64
#   CUDA Sanitizer
#
# cuda-sanitizer-12-1/unknown 12.1.105-1 amd64
#   CUDA Sanitizer
#
# cuda-sanitizer-12-2/unknown,now 12.2.140-1 amd64 [installed,automatic]
#   CUDA Sanitizer
#
# cuda-sanitizer-12-3/unknown 12.3.101-1 amd64
#   CUDA Sanitizer
#
# cuda-sanitizer-12-4/unknown 12.4.127-1 amd64
#   CUDA Sanitizer
#
# cuda-toolkit/unknown 12.4.1-1 amd64
#   CUDA Toolkit meta-package
#
# cuda-toolkit-11-7/unknown 11.7.1-1 amd64
#   CUDA Toolkit 11.7 meta-package
#
# cuda-toolkit-11-7-config-common/unknown 11.7.99-1 all
#   Common config package for CUDA Toolkit 11.7.
#
# cuda-toolkit-11-8/unknown 11.8.0-1 amd64
#   CUDA Toolkit 11.8 meta-package
#
# cuda-toolkit-11-8-config-common/unknown 11.8.89-1 all
#   Common config package for CUDA Toolkit 11.8.
#
# cuda-toolkit-11-config-common/unknown 11.8.89-1 all
#   Common config package for CUDA Toolkit 11.
#
# cuda-toolkit-12/unknown 12.4.1-1 amd64
#   CUDA Toolkit 12 meta-package
#
# cuda-toolkit-12-0/unknown 12.0.1-1 amd64
#   CUDA Toolkit 12.0 meta-package
#
# cuda-toolkit-12-0-config-common/unknown 12.0.146-1 all
#   Common config package for CUDA Toolkit 12.0.
#
# cuda-toolkit-12-1/unknown 12.1.1-1 amd64
#   CUDA Toolkit 12.1 meta-package
#
# cuda-toolkit-12-1-config-common/unknown 12.1.105-1 all
#   Common config package for CUDA Toolkit 12.1.
#
# cuda-toolkit-12-2/unknown 12.2.2-1 amd64
#   CUDA Toolkit 12.2 meta-package
#
# cuda-toolkit-12-2-config-common/unknown,now 12.2.140-1 all [installed,automatic]
#   Common config package for CUDA Toolkit 12.2.
#
# cuda-toolkit-12-3/unknown 12.3.2-1 amd64
#   CUDA Toolkit 12.3 meta-package
#
# cuda-toolkit-12-3-config-common/unknown 12.3.101-1 all
#   Common config package for CUDA Toolkit 12.3.
#
# cuda-toolkit-12-4/unknown 12.4.1-1 amd64
#   CUDA Toolkit 12.4 meta-package
#
# cuda-toolkit-12-4-config-common/unknown 12.4.127-1 all
#   Common config package for CUDA Toolkit 12.4.
#
# cuda-toolkit-12-config-common/unknown 12.4.127-1 all [upgradable from: 12.3.52-1]
#   Common config package for CUDA Toolkit 12.
#
# cuda-toolkit-config-common/unknown 12.4.127-1 all [upgradable from: 12.3.52-1]
#   Common config package for CUDA Toolkit.
#
# cuda-tools-11-7/unknown 11.7.1-1 amd64
#   CUDA Tools meta-package
#
# cuda-tools-11-8/unknown 11.8.0-1 amd64
#   CUDA Tools meta-package
#
# cuda-tools-12-0/unknown 12.0.1-1 amd64
#   CUDA Tools meta-package
#
# cuda-tools-12-1/unknown 12.1.1-1 amd64
#   CUDA Tools meta-package
#
# cuda-tools-12-2/unknown 12.2.2-1 amd64
#   CUDA Tools meta-package
#
# cuda-tools-12-3/unknown 12.3.2-1 amd64
#   CUDA Tools meta-package
#
# cuda-tools-12-4/unknown 12.4.1-1 amd64
#   CUDA Tools meta-package
#
# cuda-visual-tools-11-7/unknown 11.7.1-1 amd64
#   CUDA visual tools
#
# cuda-visual-tools-11-8/unknown 11.8.0-1 amd64
#   CUDA visual tools
#
# cuda-visual-tools-12-0/unknown 12.0.1-1 amd64
#   CUDA visual tools
#
# cuda-visual-tools-12-1/unknown 12.1.1-1 amd64
#   CUDA visual tools
#
# cuda-visual-tools-12-2/unknown 12.2.2-1 amd64
#   CUDA visual tools
#
# cuda-visual-tools-12-3/unknown 12.3.2-1 amd64
#   CUDA visual tools
#
# cuda-visual-tools-12-4/unknown 12.4.1-1 amd64
#   CUDA visual tools
#
# cudnn/unknown 9.1.1-1 amd64
#   NVIDIA CUDA Deep Neural Network library (cuDNN)
#
# cudnn9/unknown 9.1.1-1 amd64
#   NVIDIA CUDA Deep Neural Network library (cuDNN)
#
# cudnn9-cuda-11/unknown 9.1.1.17-1 amd64
#   NVIDIA cuDNN for CUDA 11
#
# cudnn9-cuda-11-8/unknown 9.1.1.17-1 amd64
#   NVIDIA cuDNN for CUDA 11.8
#
# cudnn9-cuda-12/unknown 9.1.1.17-1 amd64
#   NVIDIA cuDNN for CUDA 12
#
# cudnn9-cuda-12-3/unknown 9.0.0.312-1 amd64
#   NVIDIA cuDNN for CUDA 12.3
#
# cudnn9-cuda-12-4/unknown 9.1.1.17-1 amd64
#   NVIDIA cuDNN for CUDA 12.4
#
# cudss-cuda-12/unknown 0.2.1.3-1 amd64
#   NVIDIA cuDSS for CUDA 12
#
# cuquantum-cuda-11/unknown 24.03.0.4-1 amd64
#   NVIDIA cuQuantum SDK for CUDA 11
#
# cuquantum-cuda-12/unknown 24.03.0.4-1 amd64
#   NVIDIA cuQuantum SDK for CUDA 12
#
# cuquantum-dev/unknown 24.03.0-1 amd64
#   Transitional package to libcuquantum0-dev-cuda-11 and libcuquantum0-static-cuda-11
#
# cusolvermp-cuda-11/unknown 0.5.0.664-1 amd64
#   NVIDIA cuSOLVERMp for CUDA 11
#
# cusolvermp-cuda-12/unknown 0.5.0.664-1 amd64
#   NVIDIA cuSOLVERMp for CUDA 12
#
# libcal-cuda-11/unknown 0.4.3.36-1 amd64
#   NVIDIA cal library for CUDA 11
#
# libcal-cuda-12/unknown 0.4.3.36-1 amd64
#   NVIDIA cal library for CUDA 12
#
# libcal0-cuda-11/unknown 0.4.3.36-1 amd64
#   Runtime libraries for libcal for CUDA 11
#
# libcal0-cuda-12/unknown 0.4.3.36-1 amd64
#   Runtime libraries for libcal for CUDA 12
#
# libcal0-dev-cuda-11/unknown 0.4.3.36-1 amd64
#   Development headers and symlinks for libcal for CUDA 11
#
# libcal0-dev-cuda-12/unknown 0.4.3.36-1 amd64
#   Development headers and symlinks for libcal for CUDA 12
#
# libcub-dev/jammy 1.15.0-3 all
#   reusable software components for the CUDA programming model
#
# libcublasmp0-cuda-11/unknown 0.2.0.385-1 amd64
#   Runtime libraries for libcublasmp for CUDA 11
#
# libcublasmp0-cuda-12/unknown 0.2.0.385-1 amd64
#   Runtime libraries for libcublasmp for CUDA 12
#
# libcublasmp0-dev-cuda-11/unknown 0.2.0.385-1 amd64
#   Development headers and symlinks for libcublasmp for CUDA 11
#
# libcublasmp0-dev-cuda-12/unknown 0.2.0.385-1 amd64
#   Development headers and symlinks for libcublasmp for CUDA 12
#
# libcuda1-340/jammy 340.108-0ubuntu8 amd64
#   Transitional package for xserver-xorg-video-nouveau
#
# libcuda1-384/jammy-updates,jammy-security,jammy 390.157-0ubuntu0.22.04.2 amd64
#   Transitional package for nvidia-headless-390
#
# libcudart11.0/jammy 11.5.117~11.5.1-1ubuntu1 amd64
#   NVIDIA CUDA Runtime Library
#
# libcudnn9-cuda-11/unknown 9.1.1.17-1 amd64
#   cuDNN runtime libraries for CUDA 11.8
#
# libcudnn9-cuda-12/unknown 9.1.1.17-1 amd64
#   cuDNN runtime libraries for CUDA 12.4
#
# libcudnn9-dev-cuda-11/unknown 9.1.1.17-1 amd64
#   cuDNN development headers and symlinks for CUDA 11.8
#
# libcudnn9-dev-cuda-12/unknown 9.1.1.17-1 amd64
#   cuDNN development headers and symlinks for CUDA 12.4
#
# libcudnn9-static-cuda-11/unknown 9.1.1.17-1 amd64
#   cuDNN static libraries for CUDA 11.8
#
# libcudnn9-static-cuda-12/unknown 9.1.1.17-1 amd64
#   cuDNN static libraries for CUDA 12.4
#
# libcudss0-cuda-12/unknown 0.2.1.3-1 amd64
#   Runtime libraries for libcudss for CUDA 12
#
# libcudss0-dev-cuda-12/unknown 0.2.1.3-1 amd64
#   Development headers and symlinks for libcudss for CUDA 12
#
# libcudss0-static-cuda-12/unknown 0.2.1.3-1 amd64
#   Static libraries for libcudss for CUDA 12
#
# libcufile-11-7/unknown 1.3.1.18-1 amd64
#   Library for GPU Direct Storage with CUDA 11.7
#
# libcufile-11-8/unknown 1.4.0.31-1 amd64
#   Library for GPU Direct Storage with CUDA 11.8
#
# libcufile-12-0/unknown 1.5.1.14-1 amd64
#   Library for GPU Direct Storage with CUDA 12.0
#
# libcufile-12-1/unknown 1.6.1.9-1 amd64
#   Library for GPU Direct Storage with CUDA 12.1
#
# libcufile-12-2/unknown,now 1.7.2.10-1 amd64 [installed,automatic]
#   Library for GPU Direct Storage with CUDA 12.2
#
# libcufile-12-3/unknown 1.8.1.2-1 amd64
#   Library for GPU Direct Storage with CUDA 12.3
#
# libcufile-12-4/unknown 1.9.1.3-1 amd64
#   Library for GPU Direct Storage with CUDA 12.4
#
# libcupti-dev/jammy 11.5.114~11.5.1-1ubuntu1 amd64
#   NVIDIA CUDA Profiler Tools Interface development files
#
# libcupti-doc/jammy 11.5.114~11.5.1-1ubuntu1 all
#   NVIDIA CUDA Profiler Tools Interface documentation
#
# libcupti11.5/jammy 11.5.114~11.5.1-1ubuntu1 amd64
#   NVIDIA CUDA Profiler Tools Interface runtime library
#
# libcuquantum0-cuda-11/unknown 24.03.0.4-1 amd64
#   Runtime libraries for libcuquantum for CUDA 11
#
# libcuquantum0-cuda-12/unknown 24.03.0.4-1 amd64
#   Runtime libraries for libcuquantum for CUDA 12
#
# libcuquantum0-dev-cuda-11/unknown 24.03.0.4-1 amd64
#   Development headers and symlinks for libcuquantum for CUDA 11
#
# libcuquantum0-dev-cuda-12/unknown 24.03.0.4-1 amd64
#   Development headers and symlinks for libcuquantum for CUDA 12
#
# libcuquantum0-static-cuda-11/unknown 24.03.0.4-1 amd64
#   Static libraries for libcuquantum for CUDA 11
#
# libcuquantum0-static-cuda-12/unknown 24.03.0.4-1 amd64
#   Static libraries for libcuquantum for CUDA 12
#
# libcusolver-11-7/unknown 11.4.0.1-1 amd64
#   CUDA solver native runtime libraries
#
# libcusolver-11-8/unknown 11.4.1.48-1 amd64
#   CUDA solver native runtime libraries
#
# libcusolver-12-0/unknown 11.4.3.1-1 amd64
#   CUDA solver native runtime libraries
#
# libcusolver-12-1/unknown 11.4.5.107-1 amd64
#   CUDA solver native runtime libraries
#
# libcusolver-12-2/unknown,now 11.5.2.141-1 amd64 [installed,automatic]
#   CUDA solver native runtime libraries
#
# libcusolver-12-3/unknown 11.5.4.101-1 amd64
#   CUDA solver native runtime libraries
#
# libcusolver-12-4/unknown 11.6.1.9-1 amd64
#   CUDA solver native runtime libraries
#
# libcusolver-dev-11-7/unknown 11.4.0.1-1 amd64
#   CUDA solver native dev links, headers
#
# libcusolver-dev-11-8/unknown 11.4.1.48-1 amd64
#   CUDA solver native dev links, headers
#
# libcusolver-dev-12-0/unknown 11.4.3.1-1 amd64
#   CUDA solver native dev links, headers
#
# libcusolver-dev-12-1/unknown 11.4.5.107-1 amd64
#   CUDA solver native dev links, headers
#
# libcusolver-dev-12-2/unknown,now 11.5.2.141-1 amd64 [installed,automatic]
#   CUDA solver native dev links, headers
#
# libcusolver-dev-12-3/unknown 11.5.4.101-1 amd64
#   CUDA solver native dev links, headers
#
# libcusolver-dev-12-4/unknown 11.6.1.9-1 amd64
#   CUDA solver native dev links, headers
#
# libcusolvermp0-cuda-11/unknown 0.5.0.664-1 amd64
#   Runtime libraries for libcusolvermp for CUDA 11
#
# libcusolvermp0-cuda-12/unknown 0.5.0.664-1 amd64
#   Runtime libraries for libcusolvermp for CUDA 12
#
# libcusolvermp0-dev-cuda-11/unknown 0.5.0.664-1 amd64
#   Development headers and symlinks for libcusolvermp for CUDA 11
#
# libcusolvermp0-dev-cuda-12/unknown 0.5.0.664-1 amd64
#   Development headers and symlinks for libcusolvermp for CUDA 12
#
# libnvidia-compute-515/unknown 515.105.01-0ubuntu1 amd64
#   NVIDIA libcompute package
#
# libnvidia-compute-520/unknown 520.61.05-0ubuntu1 amd64
#   NVIDIA libcompute package
#
# libnvidia-compute-525/unknown 525.147.05-0ubuntu1 amd64
#   NVIDIA libcompute package
#
# libnvidia-decode-515/unknown 515.105.01-0ubuntu1 amd64
#   NVIDIA Video Decoding runtime libraries
#
# libnvidia-decode-520/unknown 520.61.05-0ubuntu1 amd64
#   NVIDIA Video Decoding runtime libraries
#
# libnvidia-decode-525/unknown 525.147.05-0ubuntu1 amd64
#   NVIDIA Video Decoding runtime libraries
#
# libnvimgcodec-cuda-11/unknown 0.2.0.6-1 amd64
#   Development headers and symlinks for nvImageCodec for CUDA
#
# libnvimgcodec-cuda-12/unknown 0.2.0.6-1 amd64
#   Runtime libraries for nvImageCodec for CUDA
#
# libnvjpeg2k-dev/unknown 0.8.0.38-1 amd64
#   Transitional package to libnvjpeg2k0-dev-cuda-X and libnvjpeg2k0-static-cuda-X
#
# libnvjpeg2k0/unknown 0.8.0.38-1 amd64
#   Transitional package to libnvjpeg2k0-cuda-X
#
# libnvjpeg2k0-cuda-11/unknown 0.8.0.38-1 amd64
#   Runtime libraries for libnvjpeg2k for CUDA 11
#
# libnvjpeg2k0-cuda-12/unknown 0.8.0.38-1 amd64
#   Runtime libraries for libnvjpeg2k for CUDA 12
#
# libnvjpeg2k0-dev-cuda-11/unknown 0.8.0.38-1 amd64
#   Development headers and symlinks for libnvjpeg2k for CUDA 11
#
# libnvjpeg2k0-dev-cuda-12/unknown 0.8.0.38-1 amd64
#   Development headers and symlinks for libnvjpeg2k for CUDA 12
#
# libnvjpeg2k0-static-cuda-11/unknown 0.8.0.38-1 amd64
#   Static libraries for libnvjpeg2k for CUDA 11
#
# libnvjpeg2k0-static-cuda-12/unknown 0.8.0.38-1 amd64
#   Static libraries for libnvjpeg2k for CUDA 12
#
# libnvrtc-builtins11.5/jammy 11.5.119~11.5.1-1ubuntu1 amd64
#   CUDA Runtime Compilation (NVIDIA NVRTC Builtins Library)
#
# libnvrtc11.2/jammy 11.5.119~11.5.1-1ubuntu1 amd64
#   CUDA Runtime Compilation (NVIDIA NVRTC Library)
#
# libnvtiff0-cuda-11/unknown 0.3.1.56-1 amd64
#   Runtime libraries for libnvtiff for CUDA 11
#
# libnvtiff0-cuda-12/unknown 0.3.1.56-1 amd64
#   Runtime libraries for libnvtiff for CUDA 12
#
# libnvtiff0-dev-cuda-11/unknown 0.3.1.56-1 amd64
#   Development headers and symlinks for libnvtiff for CUDA 11
#
# libnvtiff0-dev-cuda-12/unknown 0.3.1.56-1 amd64
#   Development headers and symlinks for libnvtiff for CUDA 12
#
# libnvtiff0-static-cuda-11/unknown 0.3.1.56-1 amd64
#   Static libraries for libnvtiff for CUDA 11
#
# libnvtiff0-static-cuda-12/unknown 0.3.1.56-1 amd64
#   Static libraries for libnvtiff for CUDA 12
#
# libspfft-dev/jammy 1.0.6-1 amd64
#   Sparse 3D FFT library with MPI, OpenMP, CUDA / ROCm support (development files)
#
# libspfft1/jammy 1.0.6-1 amd64
#   Sparse 3D FFT library with MPI, OpenMP, CUDA / ROCm support
#
# libvkfft-dev/jammy 1.2.17+ds1-1 all
#   Vulkan/CUDA/HIP/OpenCL Fast Fourier Transform library
#
# nsight-compute-2022.2.0/unknown 2022.2.0.13-1 amd64
#   NVIDIA Nsight Compute
#
# nsight-compute-2022.2.1/unknown 2022.2.1.3-1 amd64
#   NVIDIA Nsight Compute
#
# nsight-compute-2022.3.0/unknown 2022.3.0.22-1 amd64
#   NVIDIA Nsight Compute
#
# nsight-compute-2022.4.0/unknown 2022.4.0.15-1 amd64
#   NVIDIA Nsight Compute
#
# nsight-compute-2022.4.1/unknown 2022.4.1.6-1 amd64
#   NVIDIA Nsight Compute
#
# nsight-compute-2023.1.0/unknown 2023.1.0.15-1 amd64
#   NVIDIA Nsight Compute
#
# nsight-compute-2023.1.1/unknown 2023.1.1.4-1 amd64
#   NVIDIA Nsight Compute
#
# nsight-compute-2023.2.0/unknown 2023.2.0.16-1 amd64
#   NVIDIA Nsight Compute
#
# nsight-compute-2023.2.1/unknown 2023.2.1.3-1 amd64
#   NVIDIA Nsight Compute
#
# nsight-compute-2023.2.2/unknown,now 2023.2.2.3-1 amd64 [installed,automatic]
#   NVIDIA Nsight Compute
#
# nsight-compute-2023.3.0/unknown 2023.3.0.12-1 amd64
#   NVIDIA Nsight Compute
#
# nsight-compute-2023.3.1/unknown 2023.3.1.1-1 amd64
#   NVIDIA Nsight Compute
#
# nsight-compute-2024.1.0/unknown 2024.1.0.13-1 amd64
#   NVIDIA Nsight Compute
#
# nsight-compute-2024.1.1/unknown 2024.1.1.4-1 amd64
#   NVIDIA Nsight Compute
#
# nvidia-compute-utils-515/unknown 515.105.01-0ubuntu1 amd64
#   NVIDIA compute utilities
#
# nvidia-compute-utils-520/unknown 520.61.05-0ubuntu1 amd64
#   NVIDIA compute utilities
#
# nvidia-compute-utils-525/unknown 525.147.05-0ubuntu1 amd64
#   NVIDIA compute utilities
#
# nvidia-cuda-dev/jammy 11.5.1-1ubuntu1 amd64
#   NVIDIA CUDA development files
#
# nvidia-cuda-gdb/jammy 11.5.114~11.5.1-1ubuntu1 amd64
#   NVIDIA CUDA Debugger (GDB)
#
# nvidia-cuda-toolkit/jammy 11.5.1-1ubuntu1 amd64
#   NVIDIA CUDA development toolkit
#
# nvidia-cuda-toolkit-doc/jammy 11.5.1-1ubuntu1 all
#   NVIDIA CUDA and OpenCL documentation
#
# nvidia-cuda-toolkit-gcc/jammy 11.5.1-1ubuntu1 amd64
#   NVIDIA CUDA development toolkit (GCC compatibility)
#
# nvidia-cudnn/jammy 8.2.4.15~cuda11.4 amd64
#   NVIDIA CUDA Deep Neural Network library (install script)
#
# nvidia-gds-11-7/unknown 11.7.1-1 amd64
#   GPU Direct Storage 11.7 meta-package
#
# nvidia-gds-11-8/unknown 11.8.0-1 amd64
#   GPU Direct Storage 11.8 meta-package
#
# nvidia-gds-12-0/unknown 12.0.1-1 amd64
#   GPU Direct Storage 12.0 meta-package
#
# nvidia-gds-12-1/unknown 12.1.1-1 amd64
#   GPU Direct Storage 12.1 meta-package
#
# nvidia-gds-12-2/unknown 12.2.2-1 amd64
#   GPU Direct Storage 12.2 meta-package
#
# nvidia-gds-12-3/unknown 12.3.2-1 amd64
#   GPU Direct Storage 12.3 meta-package
#
# nvidia-gds-12-4/unknown 12.4.1-1 amd64
#   GPU Direct Storage 12.4 meta-package
#
# nvidia-headless-515/unknown 515.105.01-0ubuntu1 amd64
#   NVIDIA headless metapackage
#
# nvidia-headless-520/unknown 520.61.05-0ubuntu1 amd64
#   NVIDIA headless metapackage
#
# nvidia-headless-525/unknown 525.147.05-0ubuntu1 amd64
#   NVIDIA headless metapackage
#
# nvidia-headless-no-dkms-515/unknown 515.105.01-0ubuntu1 amd64
#   NVIDIA headless metapackage - no DKMS
#
# nvidia-headless-no-dkms-520/unknown 520.61.05-0ubuntu1 amd64
#   NVIDIA headless metapackage - no DKMS
#
# nvidia-headless-no-dkms-525/unknown 525.147.05-0ubuntu1 amd64
#   NVIDIA headless metapackage - no DKMS
#
# nvidia-profiler/jammy 11.5.114~11.5.1-1ubuntu1 amd64
#   NVIDIA Profiler for CUDA and OpenCL
#
# nvidia-visual-profiler/jammy 11.5.114~11.5.1-1ubuntu1 amd64
#   NVIDIA Visual Profiler for CUDA and OpenCL
#
# nvjpeg2k-cuda-11/unknown 0.8.0.38-1 amd64
#   NVIDIA nvJPEG 2000 for CUDA 11
#
# nvjpeg2k-cuda-12/unknown 0.8.0.38-1 amd64
#   NVIDIA nvJPEG 2000 for CUDA 12
#
# nvtiff-cuda-11/unknown 0.3.1.56-1 amd64
#   NVIDIA nvTIFF for CUDA 11
#
# nvtiff-cuda-12/unknown 0.3.1.56-1 amd64
#   NVIDIA nvTIFF for CUDA 12
#
# python-pycuda-doc/jammy 2021.1~dfsg-2build2 all
#   module to access Nvidia‘s CUDA computation API (documentation)
#
# python3-pycuda/jammy 2021.1~dfsg-2build2 amd64
#   Python 3 module to access Nvidia‘s CUDA parallel computation API
#
# python3-pyhst2-cuda/jammy 2020c-5build1 amd64
#   Python High Speed Tomographic reconstruction
#
# python3-pyvkfft/jammy 2022.1.1-2build1 amd64
#   binding to the CUDA and OpenCL backends of VkFFT - Python3
#
# relion-cuda/jammy 3.1.0-2 amd64
#   parallel toolkit for 3D reconstructions in cryo-electron microscopy
#
# relion-gui-cuda/jammy 3.1.0-2 amd64
#   parallel toolkit for 3D reconstructions in cryo-electron microscopy

# %%
# !nvidia-smi
# Out:
# Sun May 19 00:39:27 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
# %%writefile multiply_blocks_threads.cu
# #include
# #include
#
# // Kernel function to multiply the elements of two arrays
# _global_
# void multiply(int n, float *x, float *y, float *z)
# {
#     int index = threadIdx.x + blockIdx.x * blockDim.x;
#     int stride = blockDim.x * gridDim.x;
#     for (int i = index; i < n; i += stride)
#         z[i] = x[i] * y[i];
# }
#
# int main(void)
# {
#     int N = 1<<20;
#     float *x, *y, *z;
#
#     // Allocate Unified Memory – accessible from CPU or GPU
#     cudaMallocManaged(&x, N*sizeof(float));
#     cudaMallocManaged(&y, N*sizeof(float));
#     cudaMallocManaged(&z, N*sizeof(float));
#
#     // initialize x and y arrays on the host
#     for (int i = 0; i < N; i++) {
#         x[i] = 1.0f;
#         y[i] = 2.0f;
#     }
#
#     // Run kernel on 1M elements on the GPU
#     int threadsPerBlock = 256; // Define the number of threads per block
#     int numBlocks = (N + threadsPerBlock - 1) / threadsPerBlock; // Calculate the number of blocks needed
#     multiply<<>>(N, x, y, z);
#
#     // Wait for GPU to finish before accessing on host
#     cudaDeviceSynchronize();
#
#     // Check for errors (all values should be 2.0f)
#     float maxError = 0.0f;
#     for (int i = 0; i < N; i++)
#         maxError = fmax(maxError, fabs(z[i]-2.0f));
#     std::cout << "Max error: " << maxError << std::endl;
#
#     // Free memory
#     cudaFree(x);
#     cudaFree(y);
#     cudaFree(z);
#
#     return 0;
# }
# Out:
# Overwriting multiply_blocks_threads.cu

# %%
# !nvcc -o add_cuda add.cu

# %%
# !nvprof ./add_cuda
# Out:
# ==24779== NVPROF is profiling process 24779, command: ./add_cuda
# Max error: 0
# ==24779== Profiling application: ./add_cuda
# ==24779== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:  100.00%  109.55ms         1  109.55ms  109.55ms  109.55ms  add(int, float*, float*)
#       API calls:   66.48%  219.22ms         2  109.61ms  43.344us  219.18ms  cudaMallocManaged
#                    33.22%  109.56ms         1  109.56ms  109.56ms  109.56ms  cudaDeviceSynchronize
#                     0.16%  524.04us         2  262.02us  251.97us  272.07us  cudaFree
#                     0.08%  277.62us         1  277.62us  277.62us  277.62us  cudaLaunchKernel
#                     0.05%  156.15us       114  1.3690us     151ns  62.114us  cuDeviceGetAttribute
#                     0.00%  15.666us         1  15.666us  15.666us  15.666us  cuDeviceGetName
#                     0.00%  6.1930us         1  6.1930us  6.1930us  6.1930us  cuDeviceGetPCIBusId
#                     0.00%  5.3900us         1  5.3900us  5.3900us  5.3900us  cuDeviceTotalMem
#                     0.00%  1.8010us         3     600ns     244ns  1.2240us  cuDeviceGetCount
#                     0.00%  1.1480us         1  1.1480us  1.1480us  1.1480us  cuModuleGetLoadingMode
#                     0.00%  1.1110us         2     555ns     496ns     615ns  cuDeviceGet
#                     0.00%     287ns         1     287ns     287ns     287ns  cuDeviceGetUuid
#
# ==24779== Unified Memory profiling result:
# Device "Tesla T4 (0)"
#    Count  Avg Size  Min Size  Max Size  Total Size  Total Time  Name
#       48  170.67KB  4.0000KB  0.9961MB  8.000000MB  839.1170us  Host To Device
#       24  170.67KB  4.0000KB  0.9961MB  4.000000MB  366.9980us  Device To Host
#       12         -         -         -           -  3.246299ms  Gpu page fault groups
# Total CPU Page faults: 36

# %%
# !time ./add_cuda
# Out:
# Max error: 0
#
# real	0m0.350s
# user	0m0.137s
# sys	0m0.207s
